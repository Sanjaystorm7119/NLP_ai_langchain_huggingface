# %%
from nltk.stem import WordNetLemmatizer
import nltk

# nltk.download('words')
# from nltk.corpus import words


from random import sample
from nltk.corpus import wordnet
# random_words = sample(words.words(),50)

random_words = sample(list(wordnet.all_lemma_names()),50)

corpus = " ".join(random_words)

print(f"random_words : {random_words}")
print(f"corpus : {corpus}")
# Out:
# random_words : ['refined', 'dark_field_illumination', 'family_chlamydiaceae', 'uruguayan_peso', 'pinus', 'dun', 'catechetical', 'odobenidae', 'consolatory', 'reconciled', 'longness', 'contingent', 'waiting', 'backward', 'jacobinism', 'markhoor', 'varsity_sock', 'broad-leafed', 'myelin_sheath', 'chaetognathous', 'agonistic', 'golden_warbler', 'barricaded', 'sudden_death', 'sickle_alfalfa', 'genus_sphecotheres', 'tympanic_cavity', 'grabby', 'makeweight', 'cyrillic_alphabet', 'safe-deposit_box', 'single_crochet', 'oxen', 'saintpaulia_ionantha', 'immersion_heater', 'wading_pool', 'spirogyra', 'strad', 'reference_grid', 'spotted_black_bass', 'agrarian', 'service_fee', 'united_states_customary_system', 'wood_lily', "robert_e_lee's_birthday", 'flightless_bird', 'scrappy', 'chait', 'chlamyphore', 'cotton_ball']
# corpus : refined dark_field_illumination family_chlamydiaceae uruguayan_peso pinus dun catechetical odobenidae consolatory reconciled longness contingent waiting backward jacobinism markhoor varsity_sock broad-leafed myelin_sheath chaetognathous agonistic golden_warbler barricaded sudden_death sickle_alfalfa genus_sphecotheres tympanic_cavity grabby makeweight cyrillic_alphabet safe-deposit_box single_crochet oxen saintpaulia_ionantha immersion_heater wading_pool spirogyra strad reference_grid spotted_black_bass agrarian service_fee united_states_customary_system wood_lily robert_e_lee's_birthday flightless_bird scrappy chait chlamyphore cotton_ball

# %%
from nltk import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')


lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(tag):
    match tag[0]:
        case 'J':
            return wordnet.ADJ
        case 'V':
            return wordnet.VERB
        case 'N':
            return wordnet.NOUN
        case 'R':
            return wordnet.ADV
        case _:
            return wordnet.NOUN
pos_tags = nltk.pos_tag(random_words)
print(pos_tags)


lemmatized = [
    lemmatizer.lemmatize(word, get_wordnet_pos(tag))
    for word, tag in pos_tags
]

print(lemmatized)
# Out:
# [('refined', 'VBN'), ('dark_field_illumination', 'NN'), ('family_chlamydiaceae', 'NN'), ('uruguayan_peso', 'JJ'), ('pinus', 'NN'), ('dun', 'NN'), ('catechetical', 'JJ'), ('odobenidae', 'NN'), ('consolatory', 'NN'), ('reconciled', 'VBD'), ('longness', 'JJ'), ('contingent', 'NN'), ('waiting', 'VBG'), ('backward', 'JJ'), ('jacobinism', 'NN'), ('markhoor', 'NN'), ('varsity_sock', 'NN'), ('broad-leafed', 'JJ'), ('myelin_sheath', 'NN'), ('chaetognathous', 'JJ'), ('agonistic', 'JJ'), ('golden_warbler', 'NN'), ('barricaded', 'VBD'), ('sudden_death', 'NN'), ('sickle_alfalfa', 'NN'), ('genus_sphecotheres', 'VBZ'), ('tympanic_cavity', 'JJ'), ('grabby', 'NN'), ('makeweight', 'VBD'), ('cyrillic_alphabet', 'JJ'), ('safe-deposit_box', 'JJ'), ('single_crochet', 'NN'), ('oxen', 'NN'), ('saintpaulia_ionantha', 'NN'), ('immersion_heater', 'NN'), ('wading_pool', 'NN'), ('spirogyra', 'NN'), ('strad', 'NN'), ('reference_grid', 'JJ'), ('spotted_black_bass', 'NN'), ('agrarian', 'JJ'), ('service_fee', 'NN'), ('united_states_customary_system', 'JJ'), ('wood_lily', 'RB'), ("robert_e_lee's_birthday", 'JJ'), ('flightless_bird', 'NN'), ('scrappy', 'JJ'), ('chait', 'NN'), ('chlamyphore', 'NN'), ('cotton_ball', 'NN')]
# ['refine', 'dark_field_illumination', 'family_chlamydiaceae', 'uruguayan_peso', 'pinus', 'dun', 'catechetical', 'odobenidae', 'consolatory', 'reconcile', 'longness', 'contingent', 'wait', 'backward', 'jacobinism', 'markhoor', 'varsity_sock', 'broad-leafed', 'myelin_sheath', 'chaetognathous', 'agonistic', 'golden_warbler', 'barricade', 'sudden_death', 'sickle_alfalfa', 'genus_sphecotheres', 'tympanic_cavity', 'grabby', 'makeweight', 'cyrillic_alphabet', 'safe-deposit_box', 'single_crochet', 'ox', 'saintpaulia_ionantha', 'immersion_heater', 'wading_pool', 'spirogyra', 'strad', 'reference_grid', 'spotted_black_bass', 'agrarian', 'service_fee', 'united_states_customary_system', 'wood_lily', "robert_e_lee's_birthday", 'flightless_bird', 'scrappy', 'chait', 'chlamyphore', 'cotton_ball']
# [nltk_data] Downloading package wordnet to C:\Users\Sanjay
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
