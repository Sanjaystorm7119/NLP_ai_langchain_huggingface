# %%
import nltk
# from nltk.corpus import stopwords ,wordnet
from nltk.tokenize import sent_tokenize,word_tokenize


corpus = """The Impact of Technology on Modern Life

Technology has become an inseparable part of modern life, transforming the way people communicate, work, and learn. From smartphones to artificial intelligence, technological advancements have made information more accessible than ever. People can now connect across continents instantly, breaking down barriers that once limited collaboration. Education has been revolutionized by online platforms, enabling students to learn from anywhere in the world. Similarly, businesses benefit from automation and data analysis, improving efficiency and decision-making. However, technology also brings challenges. The overuse of devices can lead to decreased attention spans and social isolation. Privacy concerns have emerged as personal data becomes increasingly collected and shared. Additionally, rapid technological change can create gaps between those with access to digital tools and those without, exacerbating social inequalities. Despite these drawbacks, the overall impact of technology is overwhelmingly positive when used responsibly. Society must balance innovation with ethical considerations, ensuring that technological progress benefits humanity as a whole. In conclusion, technology shapes nearly every aspect of daily life, offering opportunities for growth and connection while demanding mindful use and regulation to prevent potential harm.
"""

# print(corpus)

sentence_tokenizer = sent_tokenize(corpus)
print(f"sentence_tokenizer : {sentence_tokenizer}")

word_tokenizer = [word_tokenize(word) for word in sentence_tokenizer]
print(f"word_tokenizer : {word_tokenizer}")


tokens = word_tokenize(corpus)
pos_tags = nltk.pos_tag(tokens)

print(f"pos_tags : {pos_tags}")
# Out:
# sentence_tokenizer : ['The Impact of Technology on Modern Life\n\nTechnology has become an inseparable part of modern life, transforming the way people communicate, work, and learn.', 'From smartphones to artificial intelligence, technological advancements have made information more accessible than ever.', 'People can now connect across continents instantly, breaking down barriers that once limited collaboration.', 'Education has been revolutionized by online platforms, enabling students to learn from anywhere in the world.', 'Similarly, businesses benefit from automation and data analysis, improving efficiency and decision-making.', 'However, technology also brings challenges.', 'The overuse of devices can lead to decreased attention spans and social isolation.', 'Privacy concerns have emerged as personal data becomes increasingly collected and shared.', 'Additionally, rapid technological change can create gaps between those with access to digital tools and those without, exacerbating social inequalities.', 'Despite these drawbacks, the overall impact of technology is overwhelmingly positive when used responsibly.', 'Society must balance innovation with ethical considerations, ensuring that technological progress benefits humanity as a whole.', 'In conclusion, technology shapes nearly every aspect of daily life, offering opportunities for growth and connection while demanding mindful use and regulation to prevent potential harm.']
# word_tokenizer : [['The', 'Impact', 'of', 'Technology', 'on', 'Modern', 'Life', 'Technology', 'has', 'become', 'an', 'inseparable', 'part', 'of', 'modern', 'life', ',', 'transforming', 'the', 'way', 'people', 'communicate', ',', 'work', ',', 'and', 'learn', '.'], ['From', 'smartphones', 'to', 'artificial', 'intelligence', ',', 'technological', 'advancements', 'have', 'made', 'information', 'more', 'accessible', 'than', 'ever', '.'], ['People', 'can', 'now', 'connect', 'across', 'continents', 'instantly', ',', 'breaking', 'down', 'barriers', 'that', 'once', 'limited', 'collaboration', '.'], ['Education', 'has', 'been', 'revolutionized', 'by', 'online', 'platforms', ',', 'enabling', 'students', 'to', 'learn', 'from', 'anywhere', 'in', 'the', 'world', '.'], ['Similarly', ',', 'businesses', 'benefit', 'from', 'automation', 'and', 'data', 'analysis', ',', 'improving', 'efficiency', 'and', 'decision-making', '.'], ['However', ',', 'technology', 'also', 'brings', 'challenges', '.'], ['The', 'overuse', 'of', 'devices', 'can', 'lead', 'to', 'decreased', 'attention', 'spans', 'and', 'social', 'isolation', '.'], ['Privacy', 'concerns', 'have', 'emerged', 'as', 'personal', 'data', 'becomes', 'increasingly', 'collected', 'and', 'shared', '.'], ['Additionally', ',', 'rapid', 'technological', 'change', 'can', 'create', 'gaps', 'between', 'those', 'with', 'access', 'to', 'digital', 'tools', 'and', 'those', 'without', ',', 'exacerbating', 'social', 'inequalities', '.'], ['Despite', 'these', 'drawbacks', ',', 'the', 'overall', 'impact', 'of', 'technology', 'is', 'overwhelmingly', 'positive', 'when', 'used', 'responsibly', '.'], ['Society', 'must', 'balance', 'innovation', 'with', 'ethical', 'considerations', ',', 'ensuring', 'that', 'technological', 'progress', 'benefits', 'humanity', 'as', 'a', 'whole', '.'], ['In', 'conclusion', ',', 'technology', 'shapes', 'nearly', 'every', 'aspect', 'of', 'daily', 'life', ',', 'offering', 'opportunities', 'for', 'growth', 'and', 'connection', 'while', 'demanding', 'mindful', 'use', 'and', 'regulation', 'to', 'prevent', 'potential', 'harm', '.']]
# pos_tags : [('The', 'DT'), ('Impact', 'NNP'), ('of', 'IN'), ('Technology', 'NNP'), ('on', 'IN'), ('Modern', 'NNP'), ('Life', 'NNP'), ('Technology', 'NNP'), ('has', 'VBZ'), ('become', 'VBN'), ('an', 'DT'), ('inseparable', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('modern', 'JJ'), ('life', 'NN'), (',', ','), ('transforming', 'VBG'), ('the', 'DT'), ('way', 'NN'), ('people', 'NNS'), ('communicate', 'VBP'), (',', ','), ('work', 'NN'), (',', ','), ('and', 'CC'), ('learn', 'NN'), ('.', '.'), ('From', 'IN'), ('smartphones', 'NNS'), ('to', 'TO'), ('artificial', 'JJ'), ('intelligence', 'NN'), (',', ','), ('technological', 'JJ'), ('advancements', 'NNS'), ('have', 'VBP'), ('made', 'VBN'), ('information', 'NN'), ('more', 'RBR'), ('accessible', 'JJ'), ('than', 'IN'), ('ever', 'RB'), ('.', '.'), ('People', 'NNS'), ('can', 'MD'), ('now', 'RB'), ('connect', 'VB'), ('across', 'IN'), ('continents', 'NNS'), ('instantly', 'RB'), (',', ','), ('breaking', 'VBG'), ('down', 'RP'), ('barriers', 'NNS'), ('that', 'WDT'), ('once', 'RB'), ('limited', 'JJ'), ('collaboration', 'NN'), ('.', '.'), ('Education', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('revolutionized', 'VBN'), ('by', 'IN'), ('online', 'NN'), ('platforms', 'NNS'), (',', ','), ('enabling', 'VBG'), ('students', 'NNS'), ('to', 'TO'), ('learn', 'VB'), ('from', 'IN'), ('anywhere', 'RB'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('Similarly', 'RB'), (',', ','), ('businesses', 'NNS'), ('benefit', 'VBP'), ('from', 'IN'), ('automation', 'NN'), ('and', 'CC'), ('data', 'NN'), ('analysis', 'NN'), (',', ','), ('improving', 'VBG'), ('efficiency', 'NN'), ('and', 'CC'), ('decision-making', 'NN'), ('.', '.'), ('However', 'RB'), (',', ','), ('technology', 'NN'), ('also', 'RB'), ('brings', 'VBZ'), ('challenges', 'NNS'), ('.', '.'), ('The', 'DT'), ('overuse', 'NN'), ('of', 'IN'), ('devices', 'NNS'), ('can', 'MD'), ('lead', 'VB'), ('to', 'TO'), ('decreased', 'JJ'), ('attention', 'NN'), ('spans', 'NNS'), ('and', 'CC'), ('social', 'JJ'), ('isolation', 'NN'), ('.', '.'), ('Privacy', 'NN'), ('concerns', 'NNS'), ('have', 'VBP'), ('emerged', 'VBN'), ('as', 'IN'), ('personal', 'JJ'), ('data', 'NNS'), ('becomes', 'NNS'), ('increasingly', 'RB'), ('collected', 'VBN'), ('and', 'CC'), ('shared', 'VBN'), ('.', '.'), ('Additionally', 'RB'), (',', ','), ('rapid', 'JJ'), ('technological', 'JJ'), ('change', 'NN'), ('can', 'MD'), ('create', 'VB'), ('gaps', 'NNS'), ('between', 'IN'), ('those', 'DT'), ('with', 'IN'), ('access', 'NN'), ('to', 'TO'), ('digital', 'JJ'), ('tools', 'NNS'), ('and', 'CC'), ('those', 'DT'), ('without', 'IN'), (',', ','), ('exacerbating', 'VBG'), ('social', 'JJ'), ('inequalities', 'NNS'), ('.', '.'), ('Despite', 'IN'), ('these', 'DT'), ('drawbacks', 'NNS'), (',', ','), ('the', 'DT'), ('overall', 'JJ'), ('impact', 'NN'), ('of', 'IN'), ('technology', 'NN'), ('is', 'VBZ'), ('overwhelmingly', 'RB'), ('positive', 'JJ'), ('when', 'WRB'), ('used', 'VBN'), ('responsibly', 'RB'), ('.', '.'), ('Society', 'NNP'), ('must', 'MD'), ('balance', 'VB'), ('innovation', 'NN'), ('with', 'IN'), ('ethical', 'JJ'), ('considerations', 'NNS'), (',', ','), ('ensuring', 'VBG'), ('that', 'IN'), ('technological', 'JJ'), ('progress', 'NN'), ('benefits', 'NNS'), ('humanity', 'NN'), ('as', 'IN'), ('a', 'DT'), ('whole', 'NN'), ('.', '.'), ('In', 'IN'), ('conclusion', 'NN'), (',', ','), ('technology', 'NN'), ('shapes', 'NNS'), ('nearly', 'RB'), ('every', 'DT'), ('aspect', 'NN'), ('of', 'IN'), ('daily', 'JJ'), ('life', 'NN'), (',', ','), ('offering', 'VBG'), ('opportunities', 'NNS'), ('for', 'IN'), ('growth', 'NN'), ('and', 'CC'), ('connection', 'NN'), ('while', 'IN'), ('demanding', 'VBG'), ('mindful', 'JJ'), ('use', 'NN'), ('and', 'CC'), ('regulation', 'NN'), ('to', 'TO'), ('prevent', 'VB'), ('potential', 'JJ'), ('harm', 'NN'), ('.', '.')]

# %%
#named entity chunk ne chunk

# nltk.download("maxent_ne_chunker")
ne_tree = nltk.ne_chunk(pos_tags)
ne_tree.draw()
