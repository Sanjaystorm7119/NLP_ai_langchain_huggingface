# %% [markdown]
# ## word embedding  (word embedding is a process of converting text into numbers)
# # word to vector or sentence to vector
#
# 2 types :
#
# -count or frequency
#     -BOW
#     -TFIDF
#     -one hot encoding
#
# -based on deep learning trained model
#     word2vec  - 2 types (ann knowledge is good to have)
#         |        - CBOW - find mid word
#         |        - Skipgram -  find surrounding word from mid word
#         |
#         |
#         |
#        / \
#       /   \
#      /     \
# pretrained scratch
#
#     fastText
#     GloVe

# %% [markdown]
# word2vec - uses neural network to learn word associations from large corpus. once trained can detect synonymns and suggest additional words for partial sentences
#
#
# as the name implies word2vec represents distinct word with a particular list of numbers called a vector

# %% [markdown]
# ## word2vec -> feature representation
#
# each and every word  that is present in the vocabulary is converted into feature representation

# %% [markdown]
# ## CBOW - continuous bag of words
#
# corpus - dataset
#         abc company is related to datascience
#
# cbow has a window size :
#
# ip                                       op
# abc company related to                   is
# company is to datascience               related
# is related datascience                   to

# %%
import gensim

from gensim.models import word2vec , keyedvectors
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king =wv['king']

print(vec_king)


# print(vec_king.shape)
# Out:
# [=======================---------------------------] 46.1% 765.8/1662.8MB downloaded

# %%
print(vec_king)
