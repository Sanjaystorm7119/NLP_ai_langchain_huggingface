# %% [markdown]
# ## skip gram -
#
# corpus - dataset
#         abc company is related to datascience
#
# skip gram has a window size :
# predicts words arounf the "target"
#
# op                                       ip
# abc company related to                   is
# company is to datascience               related
# is related datascience                   to

# %%
from scipy.stats import skew
import numpy as np
from scipy import stats

data = np.array([1,2,2,3,4,10,20])
print("Skewness:", skew(data))

transformed_data, best_lambda = stats.boxcox(data)

print("Transformed Data: \n", transformed_data)
print("Optimal λ:", best_lambda)
# Out:
# Skewness: 1.407913257045373
# Transformed Data:
#  [0.         0.62577327 0.62577327 0.93580216 1.13397147 1.66228753
#  1.97573752]
# Optimal λ: -0.3002487417984829
